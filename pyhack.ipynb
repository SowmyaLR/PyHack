# %% [markdown]
# <a href="https://colab.research.google.com/github/SowmyaLR/PyHack/blob/main/pyhack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
sample_cm_data = pd.read_excel("cm_data_sample.xlsx")

sample_cm_data.head(10)
# Out:
#      STUDYID  SITEID  ...                                            CMDECOD  SITENO
# 0  StudyHack    5163  ...  ALANINE;ARGININE;ASPARTIC ACID;CYSTEINE;GLUTAM...   53301
# 1  StudyHack    5163  ...                          GRANISETRON HYDROCHLORIDE   53301
# 2  StudyHack    5163  ...                          GRANISETRON HYDROCHLORIDE   53301
# 3  StudyHack    5163  ...  ACETYLCYSTEINE;ALANINE;ARGININE;ASCORBIC ACID;...   53301
# 4  StudyHack    5163  ...  ACETYLCYSTEINE;ALANINE;ARGININE;ASCORBIC ACID;...   53301
# 5  StudyHack    5163  ...  AMINO ACIDS NOS;COPPER;ELECTROLYTES NOS;GLUCOS...   53301
# 6  StudyHack    5163  ...                                CASPOFUNGIN ACETATE   53301
# 7  StudyHack    5163  ...                        DEXCHLORPHENIRAMINE MALEATE   53301
# 8  StudyHack    5163  ...                    HYDROCORTISONE SODIUM SUCCINATE   53301
# 9  StudyHack    5163  ...                              DEFEROXAMINE MESILATE   53301
#
# [10 rows x 49 columns]

# %%
ae_data = pd.read_excel("AE_data_sample.xlsx")
ae_data.head(10)
# Out:
#      STUDYID  SITEID    SUBJID  SUBJECTID  ...  AERELNST_ND AERELT AEOUT_C  AEOUT
# 0  StudyHack    5178  51785003     205861  ...          NaN    NaN     NaN    NaN
# 1  StudyHack    5178  51785001     156724  ...          NaN    NaN     NaN    NaN
# 2  StudyHack    5164  51645001     678844  ...          NaN    NaN     NaN    NaN
# 3  StudyHack    5521  55253014   11233277  ...          NaN    NaN     NaN    NaN
# 4  StudyHack    5521  55253014   11233277  ...          NaN    NaN     NaN    NaN
# 5  StudyHack    5525  55255001    2021912  ...          NaN    NaN     NaN    NaN
# 6  StudyHack    5035  50355004     604835  ...          NaN    NaN     NaN    NaN
# 7  StudyHack    5065  50655009    6444680  ...          NaN    NaN     NaN    NaN
# 8  StudyHack    5082  50825001    3010754  ...          NaN    NaN     NaN    NaN
# 9  StudyHack    5167  51675001     299197  ...          NaN    NaN     NaN    NaN
#
# [10 rows x 88 columns]

# %%
sample_cm_data["SUBJID"].unique()
# Out:
# array([51635003, 51735006, 51785008, 51345002, 51145051, 50785005,
#        50055005])

# %%
ae_data["SUBJID"].unique()
# Out:
# array([51785003, 51785001, 51645001, 55253014, 55255001, 50355004,
#        50655009, 50825001, 51675001, 51175004, 50945001, 51495003,
#        50945007, 51775003, 50635001, 51795013, 51855001, 51145007,
#        50655006, 55385052, 55385051])

# %%
cm_subject_list = pd.read_json("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list")

# %%
cm_sub_list = list(cm_subject_list["data"])
len(cm_sub_list)
# Out:
# 722

# %%
ae_subject_list = pd.read_json("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list")
ae_sub_list = list(ae_subject_list["data"])
len(ae_sub_list)
# Out:
# 728

# %%
def common_elements(list1, list2):
  return list(set(list1) & set(list2))

# %%
common_sub_list = common_elements(ae_sub_list, cm_sub_list)

# %%
len(common_sub_list)
# Out:
# 470

# %%
ae_data = {}
cm_data = {}

# %%
# %pip install grequests
# Out:
# Requirement already satisfied: grequests in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from grequests) (2.23.0)
# Requirement already satisfied: gevent in /usr/local/lib/python3.7/dist-packages (from grequests) (21.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->grequests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->grequests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->grequests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->grequests) (1.24.3)
# Requirement already satisfied: greenlet<2.0,>=0.4.17; platform_python_implementation == "CPython" in /usr/local/lib/python3.7/dist-packages (from gevent->grequests) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent->grequests) (54.0.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.7/dist-packages (from gevent->grequests) (4.5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.7/dist-packages (from gevent->grequests) (5.2.0)

# %%
import requests, json

# %%
# r = grequests.get("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/76809/list")
# rs = grequests.map(r)
# x = rs.request
# pd.read_json(json.dumps(x["data"]))

# %%
def get_domain_data(domain, sub_id):
  r = requests.get(f"https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/{domain}/subject/{sub_id}/list")
  x = r.json()
  return x

# %%
common_sub_list[:10]
# Out:
# [17954820,
#  3096581,
#  5857286,
#  7903241,
#  2359314,
#  4132891,
#  3479588,
#  13629484,
#  5070893,
#  3897392]

# %%
# for _i in range(0,1):
r = requests.get("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/76809/list")
x = r.json()
  # x = get_domain_data("ae", common_sub_list[_i])
if x["data"]:
  ae_data[sub] = pd.read_json(json.dumps(x["data"]))
r = requests.get("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/76809/list")
x = r.json()
  # x = get_domain_data("cm", common_sub_list[_i])
if x["data"]:
  cm_data[sub] = pd.read_json(json.dumps(x["data"]))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-183-f3a3b1f6b8b2> in <module>()
#       1 # for _i in range(0,1):
# ----> 2 r = requests.get("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/76809/list")
#       3 x = r.json()
#       4   # x = get_domain_data("ae", common_sub_list[_i])
#       5 if x["data"]:
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in connect(self)
#     330             self.ssl_context = create_urllib3_context(
#     331                 ssl_version=resolve_ssl_version(self.ssl_version),
# --> 332                 cert_reqs=resolve_cert_reqs(self.cert_reqs),
#     333             )
#     334
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/ssl_.py in create_urllib3_context(ssl_version, cert_reqs, options, ciphers)
#     277         options |= OP_NO_COMPRESSION
#     278
# --> 279     context.options |= options
#     280
#     281     context.verify_mode = cert_reqs
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
# ...
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# /usr/lib/python3.7/ssl.py in options(self, value)
#     516     @options.setter
#     517     def options(self, value):
# --> 518         super(SSLContext, SSLContext).options.__set__(self, value)
#     519
#     520     if hasattr(_ssl, 'HOSTFLAG_NEVER_CHECK_SUBJECT'):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
ae_data[common_sub_list[0]]

# %%
sub1 = pd.read_json("https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/76809/list")
type(sub1["data"])
# Out:
# pandas.core.series.Series

# %%
sub1_df = pd.json_normalize(sub1["data"])

# %%
sub1_df.columns

# %%
sub1_df.info()

# %%
sub1_df["norm_aestdat"] = pd.to_datetime(sub1_df["aestdat"]).dt.date
sub1_df["norm_aeendat"] = pd.to_datetime(sub1_df["aeendat"]).dt.date

# %%
# sub1_df = sub1_df[sub1_df["aeongo"]=="NO"]
# sub1_df = sub1_df[sub1_df['norm_aeendat'].notna()]

# %%
sub1_df[sub1_df["aeongo"]=="YES"]

# %%
sub1_df

# %%
from datetime import timedelta
(sub1_df.groupby("formid").apply(lambda x: (x['norm_aeendat'].shift() - x['norm_aestdat']) > timedelta(0)))
